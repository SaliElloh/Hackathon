# %%
import pandas as pd
import numpy as np
import PIL
import wordcloud
import requests
import pickle
from bs4 import BeautifulSoup as bsopa
import datetime
from collections import defaultdict
import re

# %%
gg=[]
for j in range(0,150,10):
    position,location='data scientist','california'
    y=requests.get('https://www.indeed.com/jobs?q={}&l={}&sort=date='.format(position,location)+str(j))

    sou=bsopa(y.text,'html.parser')

    for ii in sou.find_all('div',{"class":"jobsearch-SerpJobCard"}):

        job_title = ii.find('a', {'data-tn-element': 'jobTitle'})['title']
        company_name = ii.find('span', {'class': 'company'}).text.strip()
        location=ii.find('span',{"class":"location"})
        post_date = ii.find('span', attrs={'class': 'date'})
        summary=ii.find('div',attrs={'class':'summary'})

        if location:
            location=location.text.strip()
        else:
            location=ii.find('div',{"class":"location"})
            location=location.text.strip()

        k=ii.find('h2', {'class':"title"})
        p=k.find(href=True)
        v=p['href']
        f_=str(v).replace('&amp;','&')


        datum = {'job_title': job_title,
                    'company_name': company_name,
                    'location': location,
                    'summary':summary.text.strip(),
                    'post_Date':post_date.text,
                    'Qualification_link': f_}

        gg.append(datum)

# %%
len(gg)
# gg[0]
# Out:
# 0

# %%
hoop=[]
for i in range(len(gg)):
    op=requests.get('https://www.indeed.com'+gg[i]['Qualification_link'])
    sou_=bsopa(op.text,'html.parser')
    for ii in sou_.find('div',{'class':'jobsearch-jobDescriptionText'}):
        try:
            hoop.append([i,''.join(ii.text.strip())])
        except AttributeError:
            hoop.append([i,''])
hoop[0]
# Out:
# [0,
#  'The CompanyThe world is facing a medical crisis, bacteria are increasingly evolving resistance to even our strongest antibiotics. The problem is already very real and immediate; for example, bloodstream infection leading to sepsis is now responsible for more than half of all deaths in hospitals and is the most expensive condition treated in hospitals. Sepsis mortality rate increases >6% every hour without effective antibiotic treatment. Yet, despite the life and death urgency, and healthcare cost impacts, current methodologies require 3 days to determine the correct antibiotic.']

# %%
dct_lst= defaultdict(list)
for i in hoop:
    dct_lst[i[0]].append(i[1])
u=[]
for i in dct_lst.values(): # string join: lists of lists of strings
    u.append(''.join(i))

# %%
u[2]
# Out:
# "Our Mission\nWe’re here to create a safer, happier and more mindful future for all with the help of data science, engineering, design, and mobile technology. We're starting by reinventing insurance, by rethinking the technologies that enable it, but our true goal is to build a platform that rewards people for driving well — creating safer roads with fewer accidents in the process.\n\nBacked by impressive funding, we're poised to re-engineer a trillion-dollar category. We’re using rich customer insights, advanced technology and data science to build our cloud-native InsurTech solution. We're out to change behavior and promote mindful living.\n\nJob Requirements\nYou must have all the skills and experiences associated with one of the options below. These options change over time and reflect the current needs of the team.\nOption one - Telematics ML\nMachine learning: Kaggle grandmaster-level skills with history of deploying models to production\nTelematics experience: You have led telematics modeling at a major company known for telematics\nSoftware development in Python: Strong scientific Python skills using pandas, scikit-learn, and statsmodels, as well as strong understanding of model deployment patterns\nOption two - Telematics DL\nDeep learning: Experience contributing new deep learning research to solve previously unsolved problems\nTelematics experience: You have led telematics modeling at a major company known for telematics\nSoftware development in Python: Strong scientific Python skills using pandas, scikit-learn, and statsmodels, as well as strong understanding of model deployment patterns\nOption Three - Contact Center Optimization\nContact center knowledge: You are an expert at using data science methods to optimize contact centers\nMachine learning: Strong understanding of ML theory with significant applied experience\nSoftware development in Python: Strong scientific Python skills using pandas, scikit-learn, and statsmodels, as well as strong understanding of model deployment patterns\nMore details\nSalary: We invest in first-rate people and pay top-of-market salaries for most positions, factoring in experience, talent and location. We do not offer equity.\nBenefits: Medical, dental, vision, 401(k), wellness reimbursement, four weeks of vacation + six weeks of parental leave, and great work-life balance. Our office building offers on-site shower and bike stalls, and panoramic views of San Francisco.\nLocation: Due to COVID-19 our teams are all working remotely through 2020. We provide an in-home office set-up including laptop, monitor, ergonomic desk, chair and other items as needed\nLocation: Post COVID-19: San Francisco, CA near Montgomery Bart Station\nAll are welcome at Blue Owl. We are an equal opportunity and affirmative action employer who values diversity and inclusion and looks for applicants who understand, embrace and thrive in a multicultural world. We do not discriminate on the basis of race, color, ancestry, religion, sex, national origin, sexual orientation, age, citizenship, marital status, disability, gender identity or Veteran status. Pursuant to the San Francisco Fair Chance Ordinance, we will consider for employment qualified applicants with arrest and conviction records.\n\n If you are a San Francisco resident, please read the City and County of San Francisco's Fair Chance Ordinance notice.\nhttps://sfgov.org/olse/sites/default/files/FCO%20poster2020.pdf"

# %%
jobs_=pd.concat([pd.DataFrame(gg),pd.DataFrame(u,columns=['Qual_Text'])],axis=1)
jobs_.head()
# Out:
#                              job_title               company_name  \
# 0  Data Scientist, Medical Diagnostics       Specific Diagnostics
# 1                       Data Scientist  Laxmi Therapeutic Devices
# 2                       Data Scientist                   Blue Owl
# 3                        Data Engineer           Amick Brown, LLC
# 4                       Data Scientist                 Triplebyte
#
#                   location                                            summary  \
# 0  Mountain View, CA 94043  The development of data-driven visualization t...
# 1         Goleta, CA 93117  7+ years' practical experience manipulating da...
# 2        San Francisco, CA  We’re using rich customer insights, advanced t...
# 3            Sunnyvale, CA  Develops technical tools and programming that ...
# 4               California  You'll report directly to Triplebytes' Head of...
#
#       post_Date                                 Qualification_link  \
# 0  30+ days ago  /pagead/clk?mo=r&ad=-6NYlbfkN0ASXGwdLWjBNYivRa...
# 1   16 days ago  /pagead/clk?mo=r&ad=-6NYlbfkN0ALgD31io3l0I0Y-r...
# 2  30+ days ago  /pagead/clk?mo=r&ad=-6NYlbfkN0D3UvD5kBSgX9r9tF...
# 3         Today  /pagead/clk?mo=r&ad=-6NYlbfkN0A74pTrSPrBtiJlYH...
# 4   22 days ago  /pagead/clk?mo=r&ad=-6NYlbfkN0AMr11YIOo206dX9C...
#
#                                            Qual_Text
# 0  The CompanyThe world is facing a medical crisi...
# 1  Data ScientistLaxmi Therapeutic Devices – Gole...
# 2  Our Mission\nWe’re here to create a safer, hap...
# 3  Data EngineerSunnyvale, CAAmick Brown is seeki...
# 4  About Triplebyte\n\nTriplebyte is transforming...

# %%
import re
v=[]
for i in jobs_['post_Date']:

    if re.findall(r'[0-9]',i):
        b=''.join(re.findall(r'[0-9]',i))

        g=(datetime.datetime.today()-datetime.timedelta(int(b))).strftime('%m-%d-%Y')

        v.append(g)

    else:
        v.append(datetime.datetime.today().strftime('%m-%d-%Y'))
v[:5]
# Out:
# ['09-10-2020', '09-24-2020', '09-10-2020', '10-10-2020', '09-18-2020']

# %%
jobs_['posting_date_fixed']=v
jobs_.head()
# Out:
#                              job_title               company_name  \
# 0  Data Scientist, Medical Diagnostics       Specific Diagnostics
# 1                       Data Scientist  Laxmi Therapeutic Devices
# 2                       Data Scientist                   Blue Owl
# 3                        Data Engineer           Amick Brown, LLC
# 4                       Data Scientist                 Triplebyte
#
#                   location                                            summary  \
# 0  Mountain View, CA 94043  The development of data-driven visualization t...
# 1         Goleta, CA 93117  7+ years' practical experience manipulating da...
# 2        San Francisco, CA  We’re using rich customer insights, advanced t...
# 3            Sunnyvale, CA  Develops technical tools and programming that ...
# 4               California  You'll report directly to Triplebytes' Head of...
#
#       post_Date                                 Qualification_link  \
# 0  30+ days ago  /pagead/clk?mo=r&ad=-6NYlbfkN0ASXGwdLWjBNYivRa...
# 1   16 days ago  /pagead/clk?mo=r&ad=-6NYlbfkN0ALgD31io3l0I0Y-r...
# 2  30+ days ago  /pagead/clk?mo=r&ad=-6NYlbfkN0D3UvD5kBSgX9r9tF...
# 3         Today  /pagead/clk?mo=r&ad=-6NYlbfkN0A74pTrSPrBtiJlYH...
# 4   22 days ago  /pagead/clk?mo=r&ad=-6NYlbfkN0AMr11YIOo206dX9C...
#
#                                            Qual_Text posting_date_fixed  \
# 0  The CompanyThe world is facing a medical crisi...         09-10-2020
# 1  Data ScientistLaxmi Therapeutic Devices – Gole...         09-24-2020
# 2  Our Mission\nWe’re here to create a safer, hap...         09-10-2020
# 3  Data EngineerSunnyvale, CAAmick Brown is seeki...         10-10-2020
# 4  About Triplebyte\n\nTriplebyte is transforming...         09-18-2020
#
#                                        skill_matches
# 0                       [python, sql, visualization]
# 1              [python, sql, statistics, algorithms]
# 2  [python, machine learning, deep learning, pandas]
# 3               [python, sql, aws, machine learning]
# 4                            [aws, machine learning]

# %%
buzz_words=['Python','SQL','AWS', 'Machine learning','Deep learning','Text mining',
'NLP','SAS','Tableau','Sagemaker','Tensorflow','Spark', 'numpy', 'MongDB','PSQL',
"Postgres", 'Pandas', 'RESTFUL','NLP','Statistics','Algorithms','Visualization',
'GCP','Google Cloud','Naive Bayes','Random Forest','Bachelors degree','Masters degree'
'Java','Pyspark','Postgres','MySQL','Github','Docker','Machine Learning','C+',
'C++','Pytorch','Jupyter Notebook','R Studio','R-Studio','Forecasting','Hive',
'PhD','GCP','Numpy','NoSQL','Neo4j','Neural Network','Clustering','Linear Algebra',
'Google Colab','Data Mining','Regression','Time Series','ETL','Data Wrangling',
'Web Scraping','Feature Extraction','Featuring Engineering','Scipy','ML','DL']
buzz_words_list=[x.lower() for x in buzz_words]

yo=[]
for i in range(len(jobs_.Qual_Text)):
    a=buzz_words_list
    dd=[x for x in a if x in jobs_.Qual_Text[i].lower()]
    yo.append(dd)
jobs_['skill_matches']=yo
jobs_.head(7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 13
#      10 buzz_words_list=[x.lower() for x in buzz_words]  # convert list to lowercase to parse
#      12 yo=[]
# ---> 13 for i in range(len(jobs_.Qual_Text)):
#      14     a=buzz_words_list
#      15     dd=[x for x in a if x in jobs_.Qual_Text[i].lower()]
#
# NameError: name 'jobs_' is not defined

# %%
filename='Indeed_scrape_Oct2020.txt'
file=open(filename,'wb')
pickle.dump(jobs_,file)

file_ =open(filename,'rb')
new_file_ =pickle.load(file_)
new_file_.head(10)
# Out:
#                              job_title               company_name  \
# 0  Data Scientist, Medical Diagnostics       Specific Diagnostics
# 1                       Data Scientist  Laxmi Therapeutic Devices
# 2                       Data Scientist                   Blue Owl
# 3                        Data Engineer           Amick Brown, LLC
# 4                       Data Scientist                 Triplebyte
# 5            Data Scientist, Analytics                   Evernote
# 6                       Data Scientist                      Apple
# 7                       Data Scientist              RMDS Lab, Inc
# 8                     Data Scientist 2                       Xoom
# 9                  Data Science Intern           Parsec Education
#
#                                             location  \
# 0                            Mountain View, CA 94043
# 1                                   Goleta, CA 93117
# 2                                  San Francisco, CA
# 3                                      Sunnyvale, CA
# 4                                         California
# 5             Redwood City, CA 94063 (Downtown area)
# 6                       Santa Clara Valley, CA 95014
# 7                                     South Lake, CA
# 8  San Francisco, CA 94105 (Financial District area)
# 9                    Fresno, CA 93721 (Central area)
#
#                                              summary     post_Date  \
# 0  The development of data-driven visualization t...  30+ days ago
# 1  7+ years' practical experience manipulating da...   16 days ago
# 2  We’re using rich customer insights, advanced t...  30+ days ago
# 3  Develops technical tools and programming that ...         Today
# 4  You'll report directly to Triplebytes' Head of...   22 days ago
# 5  Apply your expertise in quantitative analysis,...    3 days ago
# 6  In-depth knowledge of digital analytics data, ...         Today
# 7  Provide consultation on data science and machi...   17 days ago
# 8  Clear subject matter expert who can help mento...         Today
# 9  Parsec Education specializes in analyzing stat...   10 days ago
#
#                                   Qualification_link  \
# 0  /pagead/clk?mo=r&ad=-6NYlbfkN0ASXGwdLWjBNYivRa...
# 1  /pagead/clk?mo=r&ad=-6NYlbfkN0ALgD31io3l0I0Y-r...
# 2  /pagead/clk?mo=r&ad=-6NYlbfkN0D3UvD5kBSgX9r9tF...
# 3  /pagead/clk?mo=r&ad=-6NYlbfkN0A74pTrSPrBtiJlYH...
# 4  /pagead/clk?mo=r&ad=-6NYlbfkN0AMr11YIOo206dX9C...
# 5  /rc/clk?jk=e6e04f20bd7ac8f1&fccid=4d2449c755ba...
# 6  /rc/clk?jk=5a488b6a19d296c3&fccid=c1099851e979...
# 7  /company/RMDS-Lab/jobs/Data-Scientist-c487fd99...
# 8  /rc/clk?jk=00c2ef3c615076e9&fccid=978d9fd9799d...
# 9  /pagead/clk?mo=r&ad=-6NYlbfkN0B5bikR7eyU0Vk4cd...
#
#                                            Qual_Text  \
# 0  The CompanyThe world is facing a medical crisi...
# 1  Data ScientistLaxmi Therapeutic Devices – Gole...
# 2  Our Mission\nWe’re here to create a safer, hap...
# 3  Data EngineerSunnyvale, CAAmick Brown is seeki...
# 4  About Triplebyte\n\nTriplebyte is transforming...
# 5  About the team:\n\nThe Evernote Analytics team...
# 6  Summary\nPosted: Oct 9, 2020\nWeekly Hours: 40...
# 7  About RMDS LabRMDS Lab and its Global Associat...
# 8  Who we are: Fueled by a fundamental belief tha...
# 9  Greetings Applicant!Here at Parsec Education w...
#
#                                        skill_matches
# 0       [python, sql, visualization, c+, c++, nosql]
# 1              [python, sql, statistics, algorithms]
# 2  [python, machine learning, deep learning, pand...
# 3  [python, sql, aws, machine learning, machine l...
# 4  [aws, machine learning, machine learning, time...
# 5  [python, sql, sas, tableau, statistics, visual...
# 6                      [sql, tableau, visualization]
# 7       [python, machine learning, machine learning]
# 8                                       [statistics]
# 9  [python, sql, machine learning, visualization,...
